# %%
import os
import pdfplumber
import pandas as pd
from difflib import SequenceMatcher

file_path = '../../1_scraping/Scrapes_ALL.csv'
# file_path = "gergo_demo.csv"
Scrape_df = pd.read_csv(file_path)
#Scrape_df.head()

# Directory where the PDFs are stored
pdf_dir = '../ScienceDirectPDF'

# Function to extract text from a PDF file using pdfplumber
def extract_text_from_pdf(pdf_file):
    try:
        with pdfplumber.open(pdf_file) as pdf:
            text = ''
            for page in pdf.pages:
                text += page.extract_text() if page.extract_text() else ''
            return text
    except Exception as e:
        print(f"Failed to extract text from {pdf_file}: {e}")
        return ""

# Function to get the title of the PDF (assumes title is in the first page)
# Function to get the title of the PDF (assumes title is in the first page)
def extract_title_from_pdf(pdf_file):
    try:
        with pdfplumber.open(pdf_file) as pdf:
            first_page_text = pdf.pages[0].extract_text()
            
            # Check if the title line starts with '## Title:'
            title_line = first_page_text.split('\n')[0]  # Assumes title is the first line
            
            if title_line.startswith("## Title:"):
                title = title_line.replace("## Title:", "").strip()
            else:
                title = title_line.strip()
                
            return title
    except Exception as e:
        print(f"Failed to extract title from {pdf_file}: {e}")
        return ""


# Helper function to find the closest matching title in Scrape_df
def find_closest_title(pdf_title, title_list):
    closest_title = None
    highest_ratio = 0
    for title in title_list:
        ratio = SequenceMatcher(None, pdf_title, title).ratio()
        if ratio > highest_ratio:
            highest_ratio = ratio
            closest_title = title
    return closest_title if highest_ratio > 0.8 else None  # Threshold for similarity

# Create a list to store the full text for each paper
full_texts = []
title_column = Scrape_df['Title'].tolist()  # List of titles in the dataframe

# Iterate over the PDF files in the pdfs directory
for pdf_file in os.listdir(pdf_dir):
    print(40 * "-")
    print(pdf_file)
    if pdf_file.endswith(".pdf"):
        pdf_path = os.path.join(pdf_dir, pdf_file)
        pdf_title = extract_title_from_pdf(pdf_path)
        
        print(pdf_title)
        
        if pdf_title:
            # Find the closest matching title in the dataframe
            matched_title = find_closest_title(pdf_title, title_column)
            
            if matched_title:
                # Extract text from the PDF
                full_text = extract_text_from_pdf(pdf_path)
                print(f'Full text extracted for "{matched_title}": {bool(full_text)}')  # Verify text extraction
                
                # Assign full text to the appropriate row in the dataframe
                Scrape_df.loc[Scrape_df['Title'] == matched_title, 'Full_Text'] = full_text
            else:
                print(f"No matching title found in the dataframe for PDF title: {pdf_title}")
        else:
            print(f"Could not extract title from PDF: {pdf_file}")
    print(40 * "-")

# Display the dataframe to verify
print("Full text successfully added to the dataframe where matches were found.")
Scrape_df.head()
# Out:
# ----------------------------------------
# .ipynb_checkpoints
# ----------------------------------------
# ----------------------------------------
# Gergo_pdfToCSV_byKata.ipynb
# ----------------------------------------
# ----------------------------------------
# science_direct_1.pdf
# BP4D-Spontaneous: a high-resolution spontaneous 3D
# No matching title found in the dataframe for PDF title: BP4D-Spontaneous: a high-resolution spontaneous 3D
# ----------------------------------------
# ----------------------------------------
# science_direct_10.pdf
# Decline or improvement?
# No matching title found in the dataframe for PDF title: Decline or improvement?
# ----------------------------------------
# ----------------------------------------
# science_direct_11.pdf
# Deep convolution network based emotion analysis towards
# Full text extracted for "Deep convolution network based emotion analysis towards mental health care": True
# ----------------------------------------
# ----------------------------------------
# science_direct_12.pdf
# Deep spatial-temporal feature fusion for facial expression
# No matching title found in the dataframe for PDF title: Deep spatial-temporal feature fusion for facial expression
# ----------------------------------------
# ----------------------------------------
# science_direct_13.pdf
# Development of a Real-Time Emotion Recognition System
# No matching title found in the dataframe for PDF title: Development of a Real-Time Emotion Recognition System
# ----------------------------------------
# ----------------------------------------
# science_direct_14.pdf
# JavaScript is disabled on your browser. Please enable JavaScript to use all
# No matching title found in the dataframe for PDF title: JavaScript is disabled on your browser. Please enable JavaScript to use all
# ----------------------------------------
# ----------------------------------------
# science_direct_15.pdf
# Emotional facial expressions evoke faster orienting
# No matching title found in the dataframe for PDF title: Emotional facial expressions evoke faster orienting
# ----------------------------------------
# ----------------------------------------
# science_direct_16.pdf
# Extended deep neural network for facial emotion recognition
# Full text extracted for "Extended deep neural network for facial emotion recognition": True
# ----------------------------------------
# ----------------------------------------
# science_direct_17.pdf
# Facial expression recognition with Convolutional Neural
# No matching title found in the dataframe for PDF title: Facial expression recognition with Convolutional Neural
# ----------------------------------------
# ----------------------------------------
# science_direct_18.pdf
# Facial Expression Recognition: A Survey
# Full text extracted for "Facial expression recognition: A survey": True
# ----------------------------------------
# ----------------------------------------
# science_direct_19.pdf
# Framework for reliable, real-time facial expression
# No matching title found in the dataframe for PDF title: Framework for reliable, real-time facial expression
# ----------------------------------------
# ----------------------------------------
# science_direct_2.pdf
# A survey on facial emotion recognition techniques: A
# Full text extracted for "A survey of 2D face recognition techniques": True
# ----------------------------------------
# ----------------------------------------
# science_direct_20.pdf
# Fusion of feature sets and classifiers for facial expression
# Full text extracted for "Fusion of feature sets and classifiers for facial expression recognition": True
# ----------------------------------------
# ----------------------------------------
# science_direct_21.pdf
# Hard negative generation for identity-disentangled facial
# Full text extracted for "Hard negative generation for identity-disentangled facial expression recognition": True
# ----------------------------------------
# ----------------------------------------
# science_direct_22.pdf
# Head pose estimation in the wild using Convolutional Neural
# No matching title found in the dataframe for PDF title: Head pose estimation in the wild using Convolutional Neural
# ----------------------------------------
# ----------------------------------------
# science_direct_23.pdf
# Hybrid deep neural networks for face emotion recognition
# Full text extracted for "Hybrid deep neural networks for face emotion recognition": True
# ----------------------------------------
# ----------------------------------------
# science_direct_24.pdf
# Multi angle optimal pattern-based deep learning for
# No matching title found in the dataframe for PDF title: Multi angle optimal pattern-based deep learning for
# ----------------------------------------
# ----------------------------------------
# science_direct_25.pdf
# Multimodal learning for facial expression recognition
# Full text extracted for "Multimodal learning for facial expression recognition": True
# ----------------------------------------
# ----------------------------------------
# science_direct_26.pdf
# On solving the face recognition problem with one training
# Full text extracted for "On solving the face recognition problem with one training sample per subject": True
# ----------------------------------------
# ----------------------------------------
# science_direct_27.pdf
# Practical emotional neural networks
# Full text extracted for "Practical emotional neural networks": True
# ----------------------------------------
# ----------------------------------------
# science_direct_28.pdf
# Shape analysis of local facial patches for 3D facial
# Full text extracted for "Shape analysis of local facial patches for 3D facial expression recognition": True
# ----------------------------------------
# ----------------------------------------
# science_direct_29.pdf
# Spatio-temporal convolutional features with nested LSTM for
# No matching title found in the dataframe for PDF title: Spatio-temporal convolutional features with nested LSTM for
# ----------------------------------------
# ----------------------------------------
# science_direct_3.pdf
# A systematic review on affective computing: emotion
# No matching title found in the dataframe for PDF title: A systematic review on affective computing: emotion
# ----------------------------------------
# ----------------------------------------
# science_direct_30.pdf
# Static topographic modeling for facial expression recognition
# Full text extracted for "Static topographic modeling for facial expression recognition and analysis": True
# ----------------------------------------
# ----------------------------------------
# science_direct_31.pdf
# Subject independent facial expression recognition with
# No matching title found in the dataframe for PDF title: Subject independent facial expression recognition with
# ----------------------------------------
# ----------------------------------------
# science_direct_32.pdf
# Three convolutional neural network models for facial
# No matching title found in the dataframe for PDF title: Three convolutional neural network models for facial
# ----------------------------------------
# ----------------------------------------
# science_direct_4.pdf
# Appearance-based gender classification with Gaussian
# Full text extracted for "Appearance-based gender classification with Gaussian processes": True
# ----------------------------------------
# ----------------------------------------
# science_direct_5.pdf
# Attention mechanism-based CNN for facial expression
# Full text extracted for "Attention mechanism-based CNN for facial expression recognition": True
# ----------------------------------------
# ----------------------------------------
# science_direct_6.pdf
# AU-inspired Deep Networks for Facial Expression Feature
# Full text extracted for "Au-inspired deep networks for facial expression feature learning": True
# ----------------------------------------
# ----------------------------------------
# science_direct_7.pdf
# Automatic coding of facial expressions displayed during
# Full text extracted for "Automatic coding of facial expressions displayed during posed and genuine pain": True
# ----------------------------------------
# ----------------------------------------
# science_direct_8.pdf
# Beyond emotion archetypes: Databases for emotion
# No matching title found in the dataframe for PDF title: Beyond emotion archetypes: Databases for emotion
# ----------------------------------------
# ----------------------------------------
# science_direct_9.pdf
# Categorization and evaluation of emotional faces in
# Full text extracted for "Categorization and evaluation of emotional faces in psychopathic women": True
# ----------------------------------------
# Full text successfully added to the dataframe where matches were found.
#    Unnamed: 0                                              Title  \
# 0           0  10 Automated Face Analysis for Affective Compu...
# 1           1  3D facial expression recognition based on auto...
# 2           2  3D facial expression recognition based on prim...
# 3           3  3D facial expression recognition based on prop...
# 4           4  3D facial expression recognition using SIFT de...
#
#                                              Authors  Year  Cited By  \
# 0                       ['JF Cohn', 'F De la Torre']  2015       170
# 1                             ['H Tang', 'TS Huang']  2008       205
# 2              ['J Wang', 'L Yin', 'X Wei', 'Y Sun']  2006       440
# 3                             ['H Tang', 'TS Huang']  2008       153
# 4  ['S Berretti', 'B Ben Amor', 'M Daoudi', 'A De...  2011       184
#
#                              Detected_Dataset  \
# 0                    Affective Faces Database
# 1  Binghamton University 3D Facial Expression
# 2  Binghamton University 3D Facial Expression
# 3  Binghamton University 3D Facial Expression
# 4  Binghamton University 3D Facial Expression
#
#                                       Detected_Topic  \
# 0                                         classifier
# 1  classification, classifier, facial expression ...
# 2                      facial expression recognition
# 3  classification, classifier, facial expression ...
# 4  classification, classifier, facial expression ...
#
#                                             Abstract     DOI  \
# 0  Differences in manual coding between databases...  No DOI
# 1  facial expression recognition from 3D facial s...  No DOI
# 2  expressions using 3D facial expression range d...  No DOI
# 3  Binghamton University have recently constructe...  No DOI
# 4  at the Binghamton University (BU-3DFE database...  No DOI
#
#                                           Journal  ... Mentions_P-value  \
# 0              The Oxford handbook of affective …  ...            False
# 1  … on computer vision and pattern recognition …  ...            False
# 2             … Vision and Pattern Recognition  …  ...            False
# 3       … on Automatic Face & Gesture Recognition  ...            False
# 4                             The Visual Computer  ...            False
#
#    Mentions_T-test  Mentions_Anova  Mentions_Correlation  Mentions_Regression  \
# 0            False           False                 False                False
# 1            False           False                 False                False
# 2            False           False                 False                False
# 3            False           False                 False                False
# 4            False           False                 False                False
#
#    Mentions_Baseline_comparison  Mentions_Mae  Mentions_Rmse  Mentions_Bias  \
# 0                         False         False          False          False
# 1                         False         False          False          False
# 2                         False         False          False          False
# 3                         False         False          False          False
# 4                         False         False          False          False
#
#    Full_Text
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 39 columns]

# %%
Scrape_df['Full_Text'].count()
# Out:
# 3

# %%
Scrape_df.to_csv('FullTextscrapes_scienceDirect.csv')
