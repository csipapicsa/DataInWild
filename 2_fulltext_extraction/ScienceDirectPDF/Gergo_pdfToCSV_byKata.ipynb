# %%
# Modified by Gergo 29-10-2024

import os

import pandas as pd
from difflib import SequenceMatcher
import science_direct_functions

# ----------------------------------------------# 
# just for reloading and dev
import importlib as imp
imp.reload(science_direct_functions)
from science_direct_functions import *
# ----------------------------------------------# 

file_path = '../../1_scraping/Scrapes_ALL.csv'

Scrape_df = pd.read_csv(file_path)
# rename Unnamed :0 to ID
Scrape_df.rename(columns = {'Unnamed: 0':'ID'}, inplace = True)
#Scrape_df.head()

# Directory where the PDFs are stored
pdf_dir = '../ScienceDirectPDF'

display(Scrape_df.head(5))
# Out:
#    ID                                              Title  \
# 0   0  10 Automated Face Analysis for Affective Compu...
# 1   1  3D facial expression recognition based on auto...
# 2   2  3D facial expression recognition based on prim...
# 3   3  3D facial expression recognition based on prop...
# 4   4  3D facial expression recognition using SIFT de...
#
#                                              Authors  Year  Cited By  \
# 0                       ['JF Cohn', 'F De la Torre']  2015       170
# 1                             ['H Tang', 'TS Huang']  2008       205
# 2              ['J Wang', 'L Yin', 'X Wei', 'Y Sun']  2006       440
# 3                             ['H Tang', 'TS Huang']  2008       153
# 4  ['S Berretti', 'B Ben Amor', 'M Daoudi', 'A De...  2011       184
#
#                              Detected_Dataset  \
# 0                    Affective Faces Database
# 1  Binghamton University 3D Facial Expression
# 2  Binghamton University 3D Facial Expression
# 3  Binghamton University 3D Facial Expression
# 4  Binghamton University 3D Facial Expression
#
#                                       Detected_Topic  \
# 0                                         classifier
# 1  classification, classifier, facial expression ...
# 2                      facial expression recognition
# 3  classification, classifier, facial expression ...
# 4  classification, classifier, facial expression ...
#
#                                             Abstract     DOI  \
# 0  Differences in manual coding between databases...  No DOI
# 1  facial expression recognition from 3D facial s...  No DOI
# 2  expressions using 3D facial expression range d...  No DOI
# 3  Binghamton University have recently constructe...  No DOI
# 4  at the Binghamton University (BU-3DFE database...  No DOI
#
#                                           Journal  ...  \
# 0              The Oxford handbook of affective …  ...
# 1  … on computer vision and pattern recognition …  ...
# 2             … Vision and Pattern Recognition  …  ...
# 3       … on Automatic Face & Gesture Recognition  ...
# 4                             The Visual Computer  ...
#
#   Mentions_Statistical_significance  Mentions_P-value  Mentions_T-test  \
# 0                             False             False            False
# 1                             False             False            False
# 2                             False             False            False
# 3                             False             False            False
# 4                             False             False            False
#
#    Mentions_Anova  Mentions_Correlation  Mentions_Regression  \
# 0           False                 False                False
# 1           False                 False                False
# 2           False                 False                False
# 3           False                 False                False
# 4           False                 False                False
#
#    Mentions_Baseline_comparison  Mentions_Mae  Mentions_Rmse  Mentions_Bias
# 0                         False         False          False          False
# 1                         False         False          False          False
# 2                         False         False          False          False
# 3                         False         False          False          False
# 4                         False         False          False          False
#
# [5 rows x 38 columns]

# %%
full_texts = []

# development reload 
imp.reload(science_direct_functions)
from science_direct_functions import *

for pdf_file in os.listdir(pdf_dir):
    if pdf_file.endswith(".pdf"):
        print(f"Processing file: {pdf_file}")
        ID = extract_numbers(pdf_file)
        pdf_path = os.path.join(pdf_dir, pdf_file)
        pdf_title = extract_title_from_pdf(pdf_path)
        full_text = extract_text_from_pdf(pdf_path)
        full_text = delete_parts_from_text(full_text, DELETE_JAVASCRIPT_TEXT)
        full_text = delete_after_references(full_text)
        full_text = remove_empty_lines(full_text)
        # print(f"Full text snippet: {full_text[:100]}")
        Scrape_df.loc[Scrape_df['ID'] == ID, 'Full_Text'] = full_text
    else:
        None
# Out:
# Processing file: science_direct_100.pdf
# Processing file: science_direct_137.pdf
# Processing file: science_direct_139.pdf
# Processing file: science_direct_143.pdf
# Processing file: science_direct_145.pdf
# Processing file: science_direct_148.pdf
# Processing file: science_direct_149.pdf
# Processing file: science_direct_154.pdf
# Processing file: science_direct_16.pdf
# Processing file: science_direct_17.pdf
# Processing file: science_direct_178.pdf
# Processing file: science_direct_185.pdf
# Processing file: science_direct_187.pdf
# Processing file: science_direct_191.pdf
# Processing file: science_direct_205.pdf
# Processing file: science_direct_208.pdf
# Processing file: science_direct_211.pdf
# Processing file: science_direct_212.pdf
# Processing file: science_direct_224.pdf
# Processing file: science_direct_32.pdf
# Processing file: science_direct_33.pdf
# Processing file: science_direct_35.pdf
# Processing file: science_direct_36.pdf
# Processing file: science_direct_42.pdf
# Processing file: science_direct_45.pdf
# Processing file: science_direct_54.pdf
# Processing file: science_direct_56.pdf
# Processing file: science_direct_67.pdf
# Processing file: science_direct_70.pdf
# Processing file: science_direct_8.pdf
# Processing file: science_direct_90.pdf

# %%
Scrape_df['Full_Text'].count()
# Out:
# 31

# %%
Scrape_df.to_csv('FullTextscrapes_scienceDirect.csv')

# %% [markdown]
# --------------------------------------------------------------

# %%
"""


# Iterate over the PDF files in the pdfs directory
for pdf_file in os.listdir(pdf_dir):
    print(40 * "-")
    print(pdf_file)
    if pdf_file.endswith(".pdf"):
        pdf_path = os.path.join(pdf_dir, pdf_file)
        pdf_title = extract_title_from_pdf(pdf_path)
        
        print(pdf_title)
        
        if pdf_title:
            # Find the closest matching title in the dataframe
            matched_title = find_closest_title(pdf_title, title_column)
            
            if matched_title:
                # Extract text from the PDF
                full_text = extract_text_from_pdf(pdf_path)
                print(f'Full text extracted for "{matched_title}": {bool(full_text)}')  # Verify text extraction
                
                # Assign full text to the appropriate row in the dataframe
                Scrape_df.loc[Scrape_df['Title'] == matched_title, 'Full_Text'] = full_text
            else:
                print(f"No matching title found in the dataframe for PDF title: {pdf_title}")
        else:
            print(f"Could not extract title from PDF: {pdf_file}")
    print(40 * "-")

# Display the dataframe to verify
print("Full text successfully added to the dataframe where matches were found.")
Scrape_df.head()

"""
