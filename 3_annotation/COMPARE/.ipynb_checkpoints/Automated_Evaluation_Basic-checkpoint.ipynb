# %%
import pandas as pd

# %% [markdown]
# # Load df

# %%
manual_data = pd.read_csv('../MANUAL/FinalLabels.csv')
automated_data = pd.read_csv('../AutomatedAnnotations_ALL.csv')

# %%
manual_data = manual_data.drop([ 'Age_A1', 'Gender_A1', 'Ethnicity_A1',
       'Age_A2', 'Gender_A2', 'Ethnicity_A2', 'Age_A3', 'Gender_A3',
       'Ethnicity_A3'], axis=1)
manual_data.head()
# Out:
#               Image FolderNames                  Final_Age Final_Gender  \
# 0  image0001063.jpg       Anger                 Baby (0-1)          Man
# 1  image0003108.jpg       Anger  Middle-aged Adult (30-49)          Man
# 2  image0006264.jpg    Contempt        Young Adult (20-29)        Woman
# 3  image0013196.jpg    Contempt              Elderly (65+)          Man
# 4  image0019021.jpg    Contempt        Young Adult (20-29)        Woman
#
#   Final_Ethnicity
# 0           White
# 1  Middle Eastern
# 2           Black
# 3           Asian
# 4           Asian

# %%
automated_data.head()
# Out:
#         datasetName folderName     imageName  Age Gender   Race
# 0  AffectNet - Test      anger  image0000006   30  Woman  white
# 1  AffectNet - Test      anger  image0000060   34    Man  white
# 2  AffectNet - Test      anger  image0000061   44    Man  white
# 3  AffectNet - Test      anger  image0000066   49    Man  white
# 4  AffectNet - Test      anger  image0000106   30    Man  black

# %% [markdown]
# # Access accuracy

# %%
# Standardize column names for merging
manual_data.rename(columns={"Image": "imageName", "FolderNames": "folderName"}, inplace=True)

# Standardize the string formats for merging columns
manual_data['imageName'] = manual_data['imageName'].str.strip().str.lower()
manual_data['folderName'] = manual_data['folderName'].str.strip().str.lower()
manual_data['Final_Ethnicity'] = manual_data['Final_Ethnicity'].str.strip().str.lower()
# Remove '.jpg' and '.png' extensions from manual image names
manual_data['imageName'] = manual_data['imageName'].str.replace('.jpg', '', regex=False).str.replace('.png', '', regex=False)

automated_data['imageName'] = automated_data['imageName'].str.strip().str.lower()
automated_data['folderName'] = automated_data['folderName'].str.strip().str.lower()

# Remove ' - Test' from datasetName in the automated dataset
automated_data['datasetName'] = automated_data['datasetName'].str.replace(' - Test', '', regex=False)

# Filter the automated dataset for 'AffectNet'
automated_data_filtered = automated_data[automated_data['datasetName'] == 'AffectNet']
#automated_data_filtered

#manual_data

# %%
merged_data_filtered = pd.merge(
    automated_data_filtered,
    manual_data,
    on=["imageName", "folderName"],
    how="inner"
)

# Define a function to map ages to categories
def age_to_category(age):
    if age <= 1:
        return "Baby (0–1 year)"
    elif 2 <= age <= 9:
        return "Child (2–9 years)"
    elif 10 <= age <= 19:
        return "Adolescent (10–19 years)"
    elif 20 <= age <= 29:
        return "Young Adult (20–29 years)"
    elif 30 <= age <= 49:
        return "Middle-aged Adult (30–49 years)"
    elif 50 <= age <= 65:
        return "Older Adult (50–65 years)"
    else:
        return "Elderly (65+ years)"

# Apply the function to the Age column
merged_data_filtered['Age'] = merged_data_filtered['Age'].apply(age_to_category)
# Convert numeric 'Age' column to string for formatting
merged_data_filtered['Age'] = merged_data_filtered['Age'].astype(str)

# Standardize string formatting for all relevant columns
merged_data_filtered['Race'] = merged_data_filtered['Race'].str.replace('/', ' ').str.strip().str.lower()
merged_data_filtered['Final_Ethnicity'] = merged_data_filtered['Final_Ethnicity'].str.replace('/', ' ').str.strip().str.lower()
merged_data_filtered['Age'] = merged_data_filtered['Age'].str.strip().str.lower()
merged_data_filtered['Final_Age'] = merged_data_filtered['Final_Age'].str.strip().str.lower()
merged_data_filtered['Gender'] = merged_data_filtered['Gender'].str.strip().str.lower()
merged_data_filtered['Final_Gender'] = merged_data_filtered['Final_Gender'].str.strip().str.lower()
# Remove the word 'years' from the 'Age' column
merged_data_filtered['Age'] = merged_data_filtered['Age'].str.replace(' years', '').str.strip()
merged_data_filtered['Age'] = (
    merged_data_filtered['Age']
    .str.replace('–', '-', regex=False)  # Replace en dash with hyphen
    .str.replace('years', '', regex=False)  # Remove the word 'years'
    .str.strip()
)


merged_data_filtered
# Out:
#    datasetName folderName     imageName                        Age Gender  \
# 0    AffectNet      anger  image0001063  middle-aged adult (30-49)  woman
# 1    AffectNet      anger  image0003108  middle-aged adult (30-49)    man
# 2    AffectNet   contempt  image0006264        young adult (20-29)  woman
# 3    AffectNet   contempt  image0013196        older adult (50-65)    man
# 4    AffectNet   contempt  image0019021  middle-aged adult (30-49)  woman
# 5    AffectNet   contempt  image0035153        older adult (50-65)    man
# 6    AffectNet    disgust       ffhq_20  middle-aged adult (30-49)    man
# 7    AffectNet    disgust       ffhq_48        young adult (20-29)    man
# 8    AffectNet    disgust  image0000866        young adult (20-29)    man
# 9    AffectNet    disgust  image0002926  middle-aged adult (30-49)    man
# 10   AffectNet    disgust  image0011562  middle-aged adult (30-49)    man
# 11   AffectNet       fear  image0001685        young adult (20-29)    man
# 12   AffectNet       fear  image0003731        young adult (20-29)    man
# 13   AffectNet       fear  image0012755        young adult (20-29)    man
# 14   AffectNet       fear  image0013449        young adult (20-29)    man
# 15   AffectNet       fear  image0016644        young adult (20-29)    man
# 16   AffectNet       fear  image0018838        young adult (20-29)    man
# 17   AffectNet      happy       ffhq_10  middle-aged adult (30-49)    man
# 18   AffectNet      happy      ffhq_164  middle-aged adult (30-49)    man
# 19   AffectNet      happy        ffhq_3  middle-aged adult (30-49)  woman
# 20   AffectNet      happy      ffhq_357  middle-aged adult (30-49)    man
# 21   AffectNet      happy        ffhq_7        young adult (20-29)  woman
# 22   AffectNet    neutral        ffhq_0        young adult (20-29)  woman
# 23   AffectNet    neutral      ffhq_107  middle-aged adult (30-49)  woman
# 24   AffectNet    neutral      ffhq_130         adolescent (10-19)    man
# 25   AffectNet    neutral      ffhq_498  middle-aged adult (30-49)    man
# 26   AffectNet    neutral       ffhq_54  middle-aged adult (30-49)    man
# 27   AffectNet    neutral       ffhq_72  middle-aged adult (30-49)    man
# 28   AffectNet    neutral      ffhq_736  middle-aged adult (30-49)    man
# 29   AffectNet        sad  image0006237  middle-aged adult (30-49)    man
# 30   AffectNet        sad  image0016204  middle-aged adult (30-49)  woman
# 31   AffectNet        sad  image0016331  middle-aged adult (30-49)  woman
# 32   AffectNet        sad  image0020274        young adult (20-29)  woman
# 33   AffectNet        sad  image0020311  middle-aged adult (30-49)    man
# 34   AffectNet   surprise       ffhq_15  middle-aged adult (30-49)    man
# 35   AffectNet   surprise       ffhq_30         adolescent (10-19)    man
# 36   AffectNet   surprise      ffhq_367        young adult (20-29)    man
# 37   AffectNet   surprise  image0023529  middle-aged adult (30-49)    man
#
#                Race                  Final_Age Final_Gender  Final_Ethnicity
# 0             white                 baby (0-1)          man            white
# 1    middle eastern  middle-aged adult (30-49)          man   middle eastern
# 2             black        young adult (20-29)        woman            black
# 3             asian              elderly (65+)          man            asian
# 4             asian        young adult (20-29)        woman            asian
# 5             white              elderly (65+)        woman            white
# 6             black        older adult (50-65)          man            black
# 7             asian                child (2-9)        woman            asian
# 8             black        young adult (20-29)          man            black
# 9             white  middle-aged adult (30-49)          man            white
# 10            asian                child (2-9)          man            black
# 11   middle eastern        young adult (20-29)        woman   middle eastern
# 12            white        young adult (20-29)          man  latino hispanic
# 13  latino hispanic         adolescent (10-19)          man  latino hispanic
# 14   middle eastern  middle-aged adult (30-49)        woman   middle eastern
# 15            asian                 baby (0-1)          man            black
# 16            white                child (2-9)          man            white
# 17  latino hispanic  middle-aged adult (30-49)        woman            white
# 18            black  middle-aged adult (30-49)          man            black
# 19            asian  middle-aged adult (30-49)        woman            asian
# 20            black                child (2-9)          man            black
# 21            asian                child (2-9)          man  latino hispanic
# 22            asian                 baby (0-1)          man  latino hispanic
# 23           indian        older adult (50-65)        woman            white
# 24            asian                child (2-9)        woman            asian
# 25           indian  middle-aged adult (30-49)          man           indian
# 26           indian  middle-aged adult (30-49)          man           indian
# 27           indian  middle-aged adult (30-49)          man            black
# 28   middle eastern        older adult (50-65)          man   middle eastern
# 29            white        older adult (50-65)          man   middle eastern
# 30            white                  ambiguous        woman            white
# 31            asian        older adult (50-65)        woman            asian
# 32            white        young adult (20-29)        woman            white
# 33            black                child (2-9)          man            black
# 34            white        young adult (20-29)          man            white
# 35            asian                child (2-9)          man        ambiguous
# 36            asian        young adult (20-29)          man            asian
# 37            white              elderly (65+)        woman            white

# %%
# Calculate accuracy for each category based on ground truth (Final labels)
age_accuracy = (merged_data_filtered['Age'] == merged_data_filtered['Final_Age']).mean() * 100
gender_accuracy = (merged_data_filtered['Gender'] == merged_data_filtered['Final_Gender']).mean() * 100
ethnicity_accuracy = (merged_data_filtered['Race'] == merged_data_filtered['Final_Ethnicity']).mean() * 100

# Calculate overall accuracy (all categories correct)
overall_accuracy = (
    (merged_data_filtered['Age'] == merged_data_filtered['Final_Age']) &
    (merged_data_filtered['Gender'] == merged_data_filtered['Final_Gender']) &
    (merged_data_filtered['Race'] == merged_data_filtered['Final_Ethnicity'])
).mean() * 100

# Print accuracy results
accuracy_results = {
    "Age Accuracy (%)": age_accuracy,
    "Gender Accuracy (%)": gender_accuracy,
    "Ethnicity Accuracy (%)": ethnicity_accuracy,
    "Overall Accuracy (%)": overall_accuracy
}

print("Accuracy Results:")
for key, value in accuracy_results.items():
    print(f"{key}: {value:.2f}%")
# Out:
# Accuracy Results:
# Age Accuracy (%): 36.84%
# Gender Accuracy (%): 73.68%
# Ethnicity Accuracy (%): 73.68%
# Overall Accuracy (%): 26.32%

# %% [markdown]
# # Cohen's Kappa
# Given that the manual annotations are considered ground truth and the automated system produces deterministic outputs (class labels), calculating Cohen's Kappa makes sense. It will evaluate the agreement between the automated system's predictions and the ground truth (manual annotations), while accounting for chance agreement.
