# %% [markdown]
# ## CK

# %%
import os
import pandas as pd
# https://github.com/serengil/deepface
from deepface import DeepFace
import matplotlib.pyplot as plt
from PIL import Image

# https://github.com/serengil/deepface
# Out:
# WARNING:tensorflow:From c:\Program Files\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Ping the downloader 
demography = DeepFace.analyze("../datasets/demo.webp")
# Out:
# Action: race: 100%|██████████| 4/4 [00:06<00:00,  1.72s/it]

# %% [markdown]
# ### Annotate CK - Test by DeepFace - Done - 2024-11-05
#
# (including angry, fear, neutral, sad, disgust, happy and surprise)

# %%
def analyze_faces_in_directory(directory, emotion_folder, expansion="", demo=False):
    # Create a DataFrame to store the analysis results
    results_df = pd.DataFrame(columns=["Image", "Age", "Gender", "Race", "Emotion"])
    results = []

    # Loop through all files in the directory

    files = os.listdir(directory)

    for demo_i, filename in enumerate(files):
        if demo and demo_i >= 5:
            break
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Add more extensions if needed
            file_path = os.path.join(directory, filename)
            try:
                # Analyze the face in the image with enforce_detection=False
                print(f"Processing {filename}")
                analysis = DeepFace.analyze(img_path=file_path, actions=['age', 'gender', 'race', 'emotion'], enforce_detection=False)

                # DeepFace returns a list, so access the first dictionary in the list
                analysis = analysis[0]

                # Extract data from the analysis dictionary
                
                #age = analysis.get('age', 'N/A')  # Use .get() to handle missing keys
                #gender = analysis.get('dominant_gender', 'N/A')  # Correct key for gender
                #race = analysis.get('dominant_race', 'N/A')  # Correct key for race
                #emotion = analysis.get('dominant_emotion', 'N/A')  # Correct key for emotion
                #print(analysis)

                result_dict = {
                    "Image": f"{emotion_folder}_-_{filename}",
                    "Age": analysis.get('age', 'N/A'),
                    "Gender": analysis.get('dominant_gender', 'N/A'),
                    "Race": analysis.get('dominant_race', 'N/A'),
                    "Emotion": analysis.get('dominant_emotion', 'N/A')
                }
                
                # Append dictionary to results list
                results.append(result_dict)

                # Print the results for the current image
                # print(f"Processed {filename}: Age: {age}, Gender: {gender}, Race: {race}")

            except Exception as e:
                # Handle the error gracefully and continue processing
                print(f"Error processing {filename}: {e}")
                continue

    # Save results to CSV for further use
    # Convert results list to DataFrame only at the end
    if results:  # Check if we have any results
        results_df = pd.DataFrame(results)
        output_file = f'face_analysis_results_{emotion_folder}_{expansion}.csv'
        results_df.to_csv(output_file, index=False)
        print(f"Analysis completed! Results saved to {output_file}")
    else:
        print("No results to save!")


# Example usage
DEMO = True
directory_path = '../datasets/ck/'
expansion = "ck"
emotion_folders = ['anger', 'disgust', 'fear', 'happy', 'sadness', 'surprise', 'contempt']
for e in emotion_folders:
    analyze_faces_in_directory(directory=f"{directory_path}/{e}", 
                               emotion_folder=e,
                               expansion=expansion,
                               demo=DEMO)
# Out:
# Processing S010_004_00000017.png
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  3.56it/s]
# Processing S010_004_00000018.png
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00,  4.10it/s]
# Processing S010_004_00000019.png
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00,  4.01it/s]
# Processing S011_004_00000019.png
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00,  4.00it/s]
# Processing S011_004_00000020.png
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00,  4.29it/s]
# Analysis completed! Results saved to face_analysis_results_anger_ck.csv
# Processing S005_001_00000009.png
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00,  4.16it/s]
# Processing S005_001_00000010.png
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  3.48it/s]
# Processing S005_001_00000011.png
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00,  4.14it/s]
# Processing S011_005_00000018.png
# Action: race:  50%|█████     | 2/4 [00:00<00:00,  2.11it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10408\773447172.py in ?()
#      63 directory_path = '../datasets/ck/'
#      64 expansion = "ck"
#      65 emotion_folders = ['anger', 'disgust', 'fear', 'happy', 'sadness', 'surprise', 'contempt']
#      66 for e in emotion_folders:
# ---> 67     analyze_faces_in_directory(directory=f"{directory_path}/{e}",
#      68                                emotion_folder=e,
#      69                                expansion=expansion,
#      70                                demo=DEMO)
#
# ~\AppData\Local\Temp\ipykernel_10408\773447172.py in ?(directory, emotion_folder, expansion, demo)
#      41
#      42                 # Print the results for the current image
#      43                 # print(f"Processed {filename}: Age: {age}, Gender: {gender}, Race: {race}")
#      44
# ---> 45             except Exception as e:
#      46                 # Handle the error gracefully and continue processing
#      47                 print(f"Error processing {filename}: {e}")
#      48                 continue
#
# c:\Program Files\Python312\Lib\site-packages\deepface\DeepFace.py in ?(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     249             - 'black': Confidence score for Black ethnicity.
#     250             - 'middle eastern': Confidence score for Middle Eastern ethnicity.
#     251             - 'white': Confidence score for White ethnicity.
#     252     """
# --> 253     return demography.analyze(
#     254         img_path=img_path,
#     255         actions=actions,
#     256         enforce_detection=enforce_detection,
#
# c:\Program Files\Python312\Lib\site-packages\deepface\modules\demography.py in ?(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     190
#     191             elif action == "race":
#     192                 race_predictions = modeling.build_model(
#     193                     task="facial_attribute", model_name="Race"
# --> 194                 ).predict(img_content)
#     195                 sum_of_predictions = race_predictions.sum()
#     196
#     197                 obj["race"] = {}
#
# c:\Program Files\Python312\Lib\site-packages\deepface\models\demography\Race.py in ?(self, img)
#      42     def predict(self, img: np.ndarray) -> np.ndarray:
#      43         # model.predict causes memory issue when it is called in a for loop
#      44         # return self.model.predict(img, verbose=0)[0, :]
# ---> 45         return self.model(img, training=False).numpy()[0, :]
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\engine\training.py in ?(self, *args, **kwargs)
#     584                 super().__call__(inputs, *copied_args, **copied_kwargs)
#     585
#     586             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     587
# --> 588         return super().__call__(*args, **kwargs)
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1132
#    1133                 with autocast_variable.enable_auto_cast_variables(
#    1134                     self._compute_dtype_object
#    1135                 ):
# -> 1136                     outputs = call_fn(inputs, *args, **kwargs)
#    1137
#    1138                 if self._activity_regularizer:
#    1139                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\engine\functional.py in ?(self, inputs, training, mask)
#     510         Returns:
#     511             A tensor if there is a single output, or
#     512             a list of tensors if there are more than one outputs.
#     513         """
# --> 514         return self._run_internal_graph(inputs, training=training, mask=mask)
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\engine\functional.py in ?(self, inputs, training, mask)
#     667                 if any(t_id not in tensor_dict for t_id in node.flat_input_ids):
#     668                     continue  # Node is not computable, try skipping.
#     669
#     670                 args, kwargs = node.map_arguments(tensor_dict)
# --> 671                 outputs = node.layer(*args, **kwargs)
#     672
#     673                 # Update tensor_dict.
#     674                 for x_id, y in zip(
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1132
#    1133                 with autocast_variable.enable_auto_cast_variables(
#    1134                     self._compute_dtype_object
#    1135                 ):
# -> 1136                     outputs = call_fn(inputs, *args, **kwargs)
#    1137
#    1138                 if self._activity_regularizer:
#    1139                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\layers\convolutional\base_conv.py in ?(self, inputs)
#     285             outputs = self._jit_compiled_convolution_op(
#     286                 inputs, tf.convert_to_tensor(self.kernel)
#     287             )
#     288         else:
# --> 289             outputs = self.convolution_op(inputs, self.kernel)
#     290
#     291         if self.use_bias:
#     292             output_rank = outputs.shape.rank
#
# c:\Program Files\Python312\Lib\site-packages\tf_keras\src\layers\convolutional\base_conv.py in ?(self, inputs, kernel)
#     257             tf_padding = self.padding.upper()
#     258         else:
#     259             tf_padding = self.padding
#     260
# --> 261         return tf.nn.convolution(
#     262             inputs,
#     263             kernel,
#     264             strides=list(self.strides),
#
# c:\Program Files\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Program Files\Python312\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Program Files\Python312\Lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(input, filters, strides, padding, data_format, dilations, name)
#    1182     padding="VALID",
#    1183     data_format=None,
#    1184     dilations=None,
#    1185     name=None):
# -> 1186   return convolution_internal(
#    1187       input,  # pylint: disable=redefined-builtin
#    1188       filters,
#    1189       strides=strides,
#
# c:\Program Files\Python312\Lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1315         op = _conv3d_expanded_batch
#    1316       else:
#    1317         op = conv1d
#    1318
# -> 1319       return op(
#    1320           input,
#    1321           filters,
#    1322           strides,
#
# c:\Program Files\Python312\Lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(input, filters, strides, padding, data_format, dilations, name)
#    2789   input_rank = input.shape.rank
#    2790   if input_rank is None or input_rank < 5:
#    2791     # We avoid calling squeeze_batch_dims to reduce extra python function
#    2792     # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2793     return gen_nn_ops.conv2d(
#    2794         input,
#    2795         filter=filters,
#    2796         strides=strides,
#
# c:\Program Files\Python312\Lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in ?(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1458         "dilations", dilations)
#    1459       return _result
#    1460     except _core._NotOkStatusException as e:
#    1461       _ops.raise_from_not_ok_status(e, name)
# -> 1462     except _core._FallbackException:
#    1463       pass
#    1464     try:
#    1465       return conv2d_eager_fallback(
#
# KeyboardInterrupt:

# %% [markdown]
# -------------------------------------------------

# %% [markdown]
# ### Evaulate Affecnet Test dataset predictions
#
# - Accuracy
#
# https://sefiks.com/2018/01/01/facial-expression-recognition-with-keras/

# %%
files = ["anger", "contempt", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
file_name = "results/AffectNet - Test/face_analysis_results_"

# Initialize empty dataframes for merging
gender_counts = pd.DataFrame()
race_counts = pd.DataFrame()

df_affectnet_ground_th = pd.read_csv("../datasets/AffectNet/labels.csv")
print(df_affectnet_ground_th.head())

# Loop through each file, read the CSV, and aggregate Gender and Race counts
for file in files:
    # file is also class name
    df = pd.read_csv(file_name + file + ".csv")
    print(df.head())
    
    # Count gender and race occurrences
    gender_count = df['Gender'].value_counts().reset_index()
    race_count = df['Race'].value_counts().reset_index()

    # Rename columns to avoid conflicts during merge
    gender_count.columns = ['Gender', 'Count']
    race_count.columns = ['Race', 'Count']

    # Append counts to the final dataframes (gender and race)
    if gender_counts.empty:
        gender_counts = gender_count
    else:
        gender_counts = pd.concat([gender_counts, gender_count])

    if race_counts.empty:
        race_counts = race_count
    else:
        race_counts = pd.concat([race_counts, race_count])

# Group by 'Gender' and 'Race' and sum up the counts
final_gender_counts = gender_counts.groupby('Gender')['Count'].sum().reset_index()
final_race_counts = race_counts.groupby('Race')['Count'].sum().reset_index()

# Plotting the distribution of Gender and Race categories
plt.figure(figsize=(12, 6))

# Plot Gender distribution
plt.subplot(1, 2, 1)
plt.bar(final_gender_counts['Gender'], final_gender_counts['Count'], color='lightblue')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')

# Plot Race distribution
plt.subplot(1, 2, 2)
plt.bar(final_race_counts['Race'], final_race_counts['Count'], color='lightgreen')
plt.title('Race Distribution')
plt.xlabel('Race')
plt.ylabel('Count')

# Show the plots
plt.tight_layout()
plt.show()
# Out:
#    Unnamed: 0                     pth     label    relFCs
# 0           0  anger/image0000006.jpg  surprise  0.873142
# 1           1  anger/image0000060.jpg     anger  0.852311
# 2           2  anger/image0000061.jpg     anger  0.800957
# 3           3  anger/image0000066.jpg   disgust  0.843079
# 4           4  anger/image0000106.jpg     anger  0.849108
#                       Image  Age Gender   Race  Emotion
# 0  anger_-_image0000006.jpg   30  Woman  white  neutral
# 1  anger_-_image0000060.jpg   34    Man  white  neutral
# 2  anger_-_image0000061.jpg   44    Man  white    happy
# 3  anger_-_image0000066.jpg   49    Man  white      sad
# 4  anger_-_image0000106.jpg   30    Man  black    angry
#                      Image  Age Gender   Race  Emotion
# 0    contempt_-_ffhq_1.png   31    Man  white  neutral
# 1   contempt_-_ffhq_10.png   32  Woman  white      sad
# 2  contempt_-_ffhq_100.png   29    Man  white     fear
# 3  contempt_-_ffhq_101.png   34  Woman  white    angry
# 4  contempt_-_ffhq_102.png   27    Man  white  neutral
#                    Image  Age Gender             Race  Emotion
# 0   disgust_-_ffhq_0.png   26  Woman            white     fear
# 1   disgust_-_ffhq_1.png   47    Man  latino hispanic  neutral
# 2  disgust_-_ffhq_10.png   39    Man   middle eastern     fear
# 3  disgust_-_ffhq_11.png   26    Man   middle eastern      sad
# 4  disgust_-_ffhq_12.png   38  Woman            white    happy
#                      Image  Age Gender             Race  Emotion
# 0  fear_-_image0000284.jpg   27  Woman            white    happy
# 1  fear_-_image0000285.jpg   29  Woman  latino hispanic      sad
# 2  fear_-_image0000419.jpg   40  Woman            asian  neutral
# 3  fear_-_image0000451.jpg   39    Man  latino hispanic  neutral
# 4  fear_-_image0000473.jpg   35    Man  latino hispanic      sad
#                    Image  Age Gender             Race Emotion
# 0     happy_-_ffhq_0.png   29    Man            white   happy
# 1     happy_-_ffhq_1.png   34  Woman            white   happy
# 2    happy_-_ffhq_10.png   32    Man  latino hispanic   happy
# 3   happy_-_ffhq_100.png   33  Woman            white   happy
# 4  happy_-_ffhq_1000.png   50    Man            white   happy
#                      Image  Age Gender   Race  Emotion
# 0     neutral_-_ffhq_0.png   23  Woman  asian  neutral
# 1     neutral_-_ffhq_1.png   25    Man  black  neutral
# 2    neutral_-_ffhq_10.png   25    Man  white    angry
# 3   neutral_-_ffhq_100.png   27    Man  asian  neutral
# 4  neutral_-_ffhq_1000.png   32    Man  white    happy
#                     Image  Age Gender             Race  Emotion
# 0  sad_-_image0000013.jpg   52    Man            asian      sad
# 1  sad_-_image0000027.jpg   23    Man            black      sad
# 2  sad_-_image0000028.jpg   35    Man  latino hispanic      sad
# 3  sad_-_image0000047.jpg   29    Man            white     fear
# 4  sad_-_image0000073.jpg   50  Woman            white  neutral
#                      Image  Age Gender             Race   Emotion
# 0    surprise_-_ffhq_1.png   33    Man            white      fear
# 1   surprise_-_ffhq_10.png   23    Man  latino hispanic  surprise
# 2  surprise_-_ffhq_100.png   33    Man   middle eastern     happy
# 3  surprise_-_ffhq_101.png   40  Woman            white      fear
# 4  surprise_-_ffhq_102.png   28  Woman            asian  surprise

# %% [markdown]
# ### Accuracy per race

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
df_affectnet_ground_th = pd.read_csv("../datasets/AffectNet/labels.csv")
files = ["anger", "contempt", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
files = ["anger", "fear", "neutral", "sad", "disgust", "happy", "surprise"]
file_name = "results/AffectNet - Test/face_analysis_results_"

# Merge the datasets based on the image filename
# Create a new column in ground truth with formatted filenames to match annotated results
df_affectnet_ground_th['Image'] = df_affectnet_ground_th['pth'].apply(lambda x: x.split('/')[-1])

# Initialize an empty DataFrame to collect all annotated results
df_results = pd.DataFrame()

# Loop through each file, read and concatenate them to a single DataFrame
for file in files:
    GROUND_TRUTH_EMOTION = file
    df = pd.read_csv(file_name + file + ".csv")
    df_results = pd.concat([df_results, df])

# Merge ground truth with predictions
df_merged = pd.merge(df_affectnet_ground_th, df_results, on='Image')

# Create a new column indicating if the prediction is correct
df_merged['Correct'] = df_merged['label'] == df_merged['Emotion']

# Calculate accuracy per gender
accuracy_per_gender = df_merged.groupby('Gender')['Correct'].mean().reset_index()

# Plot the results
plt.figure(figsize=(8, 5))
plt.bar(accuracy_per_gender['Gender'], accuracy_per_gender['Correct'], color='lightblue')
plt.title('Emotion Detection Accuracy per Gender')
plt.xlabel('Gender')
plt.ylabel('Accuracy')
plt.ylim([0, 1])  # Accuracy ranges from 0 to 1
plt.show()

# %%
df_affectnet_ground_th
# Out:
#        Unnamed: 0                        pth     label    relFCs  \
# 0               0     anger/image0000006.jpg  surprise  0.873142
# 1               1     anger/image0000060.jpg     anger  0.852311
# 2               2     anger/image0000061.jpg     anger  0.800957
# 3               3     anger/image0000066.jpg   disgust  0.843079
# 4               4     anger/image0000106.jpg     anger  0.849108
# ...           ...                        ...       ...       ...
# 28170       28170  surprise/image0034960.jpg  surprise  0.825263
# 28171       28171  surprise/image0034961.jpg  surprise  0.738646
# 28172       28172  surprise/image0034966.jpg  surprise  0.774524
# 28173       28173  surprise/image0034973.jpg   neutral  0.766952
# 28174       28174  surprise/image0042075.jpg   disgust  0.832160
#
#                   Image
# 0      image0000006.jpg
# 1      image0000060.jpg
# 2      image0000061.jpg
# 3      image0000066.jpg
# 4      image0000106.jpg
# ...                 ...
# 28170  image0034960.jpg
# 28171  image0034961.jpg
# 28172  image0034966.jpg
# 28173  image0034973.jpg
# 28174  image0042075.jpg
#
# [28175 rows x 5 columns]

# %%
df_results
# Out:
#                             Image  Age Gender             Race   Emotion
# 0        anger_-_image0000006.jpg   30  Woman            white   neutral
# 1        anger_-_image0000060.jpg   34    Man            white   neutral
# 2        anger_-_image0000061.jpg   44    Man            white     happy
# 3        anger_-_image0000066.jpg   49    Man            white       sad
# 4        anger_-_image0000106.jpg   30    Man            black     angry
# ...                           ...  ...    ...              ...       ...
# 1915  surprise_-_image0023909.jpg   16    Man            white   neutral
# 1916  surprise_-_image0023917.jpg   31  Woman            white   neutral
# 1917  surprise_-_image0023918.jpg   30  Woman            white  surprise
# 1918  surprise_-_image0023926.jpg   30    Man            black  surprise
# 1919  surprise_-_image0023930.jpg   31    Man  latino hispanic  surprise
#
# [14518 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
df_affectnet_ground_th = pd.read_csv("../datasets/AffectNet/labels.csv")

# Add a formatted Image column to match results for easier merge
df_affectnet_ground_th['Image'] = df_affectnet_ground_th['pth'].apply(lambda x: x.split('/')[-1])
df_affectnet_ground_th['label'] = df_affectnet_ground_th['pth'].apply(lambda x: x.split('/')[0])


files = ["anger", "contempt", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
files = ["anger", "fear", "neutral", "sad", "disgust", "happy", "surprise"] # DeepFace classes
# files = ["neutral"]
file_name = "results/AffectNet - Test/face_analysis_results_"

# Initialize an empty DataFrame to collect all annotated results
df_results = pd.DataFrame()

# Loop through each file, read and concatenate them to a single DataFrame
for file in files:
    df = pd.read_csv(file_name + file + ".csv")
    
    # Split the Image column to extract only the part after the first underscore
    df['Formatted_Image'] = df['Image'].apply(lambda x: x.split('_-_')[-1])  # Extract 'image0000006.jpg'
    
    # Add the GROUND_TRUTH_EMOTION to reconstruct the full path in ground truth
    df['Image'] = file + "/" + df['Formatted_Image']  # Recreate the full path format as 'anger/image0000006.jpg'
    
    df_results = pd.concat([df_results, df])

df_results.rename(columns={"Image": "pth"}, inplace=True)
# Merge ground truth with predictions using the formatted Image column
df_merged = pd.merge(df_affectnet_ground_th, df_results, on='pth')

# Create a new column indicating if the prediction is correct
df_merged['Correct'] = df_merged['label'] == df_merged['Emotion']

# Calculate accuracy per gender and emotion
# Calculate accuracy per race
accuracy_per_race = df_merged.groupby('Race')['Correct'].mean().reset_index()

# Plot the results
plt.figure(figsize=(8, 5))
plt.bar(accuracy_per_race['Race'], accuracy_per_race['Correct'], color='lightgreen')
plt.title('Emotion Detection Accuracy per Race')
plt.xlabel('Race')
plt.ylabel('Accuracy')
plt.ylim([0, 1])  # Accuracy ranges from 0 to 1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_results
# Out:
#                             pth  Age Gender             Race   Emotion  \
# 0        anger/image0000006.jpg   30  Woman            white   neutral
# 1        anger/image0000060.jpg   34    Man            white   neutral
# 2        anger/image0000061.jpg   44    Man            white     happy
# 3        anger/image0000066.jpg   49    Man            white       sad
# 4        anger/image0000106.jpg   30    Man            black     angry
# ...                         ...  ...    ...              ...       ...
# 1915  surprise/image0023909.jpg   16    Man            white   neutral
# 1916  surprise/image0023917.jpg   31  Woman            white   neutral
# 1917  surprise/image0023918.jpg   30  Woman            white  surprise
# 1918  surprise/image0023926.jpg   30    Man            black  surprise
# 1919  surprise/image0023930.jpg   31    Man  latino hispanic  surprise
#
#        Formatted_Image
# 0     image0000006.jpg
# 1     image0000060.jpg
# 2     image0000061.jpg
# 3     image0000066.jpg
# 4     image0000106.jpg
# ...                ...
# 1915  image0023909.jpg
# 1916  image0023917.jpg
# 1917  image0023918.jpg
# 1918  image0023926.jpg
# 1919  image0023930.jpg
#
# [13206 rows x 6 columns]

# %%
df_affectnet_ground_th
# Out:
#        Unnamed: 0                        pth     label    relFCs  \
# 0               0     anger/image0000006.jpg     anger  0.873142
# 1               1     anger/image0000060.jpg     anger  0.852311
# 2               2     anger/image0000061.jpg     anger  0.800957
# 3               3     anger/image0000066.jpg     anger  0.843079
# 4               4     anger/image0000106.jpg     anger  0.849108
# ...           ...                        ...       ...       ...
# 28170       28170  surprise/image0034960.jpg  surprise  0.825263
# 28171       28171  surprise/image0034961.jpg  surprise  0.738646
# 28172       28172  surprise/image0034966.jpg  surprise  0.774524
# 28173       28173  surprise/image0034973.jpg  surprise  0.766952
# 28174       28174  surprise/image0042075.jpg  surprise  0.832160
#
#                   Image
# 0      image0000006.jpg
# 1      image0000060.jpg
# 2      image0000061.jpg
# 3      image0000066.jpg
# 4      image0000106.jpg
# ...                 ...
# 28170  image0034960.jpg
# 28171  image0034961.jpg
# 28172  image0034966.jpg
# 28173  image0034973.jpg
# 28174  image0042075.jpg
#
# [28175 rows x 5 columns]

# %%
accuracy_per_race = df_merged['Correct'].mean()

# %%
df_merged['Correct'].mean()
# Out:
# 0.36336008727499414

# %%
df_merged
# Out:
#        Unnamed: 0                        pth     label    relFCs  \
# 0               0     anger/image0000006.jpg     anger  0.873142
# 1               1     anger/image0000060.jpg     anger  0.852311
# 2               2     anger/image0000061.jpg     anger  0.800957
# 3               3     anger/image0000066.jpg     anger  0.843079
# 4               4     anger/image0000106.jpg     anger  0.849108
# ...           ...                        ...       ...       ...
# 12828       26111  surprise/image0023909.jpg  surprise  0.807990
# 12829       26112  surprise/image0023917.jpg  surprise  0.775216
# 12830       26113  surprise/image0023918.jpg  surprise  0.729153
# 12831       26114  surprise/image0023926.jpg  surprise  0.777204
# 12832       26115  surprise/image0023930.jpg  surprise  0.866412
#
#                   Image  Age Gender             Race   Emotion  \
# 0      image0000006.jpg   30  Woman            white   neutral
# 1      image0000060.jpg   34    Man            white   neutral
# 2      image0000061.jpg   44    Man            white     happy
# 3      image0000066.jpg   49    Man            white       sad
# 4      image0000106.jpg   30    Man            black     angry
# ...                 ...  ...    ...              ...       ...
# 12828  image0023909.jpg   16    Man            white   neutral
# 12829  image0023917.jpg   31  Woman            white   neutral
# 12830  image0023918.jpg   30  Woman            white  surprise
# 12831  image0023926.jpg   30    Man            black  surprise
# 12832  image0023930.jpg   31    Man  latino hispanic  surprise
#
#         Formatted_Image  Correct
# 0      image0000006.jpg    False
# 1      image0000060.jpg    False
# 2      image0000061.jpg    False
# 3      image0000066.jpg    False
# 4      image0000106.jpg    False
# ...                 ...      ...
# 12828  image0023909.jpg    False
# 12829  image0023917.jpg    False
# 12830  image0023918.jpg     True
# 12831  image0023926.jpg     True
# 12832  image0023930.jpg     True
#
# [12833 rows x 11 columns]

# %%
accuracy_per_gender_emotion
# Out:
#    Gender   Emotion   Correct
# 0     Man     angry  0.000000
# 1     Man   disgust  0.639175
# 2     Man      fear  0.255692
# 3     Man     happy  0.551077
# 4     Man   neutral  0.185671
# 5     Man       sad  0.245271
# 6     Man  surprise  0.517949
# 7   Woman     angry  0.000000
# 8   Woman   disgust  0.676471
# 9   Woman      fear  0.287293
# 10  Woman     happy  0.632056
# 11  Woman   neutral  0.248815
# 12  Woman       sad  0.306525
# 13  Woman  surprise  0.612048

# %%
df_merged
# Out:
#        Unnamed: 0                        pth     label    relFCs  \
# 0               0     anger/image0000006.jpg  surprise  0.873142
# 1               1     anger/image0000060.jpg     anger  0.852311
# 2               2     anger/image0000061.jpg     anger  0.800957
# 3               3     anger/image0000066.jpg   disgust  0.843079
# 4               4     anger/image0000106.jpg     anger  0.849108
# ...           ...                        ...       ...       ...
# 14088       26111  surprise/image0023909.jpg  surprise  0.807990
# 14089       26112  surprise/image0023917.jpg   disgust  0.775216
# 14090       26113  surprise/image0023918.jpg  surprise  0.729153
# 14091       26114  surprise/image0023926.jpg  surprise  0.777204
# 14092       26115  surprise/image0023930.jpg  surprise  0.866412
#
#                   Image  Age Gender             Race   Emotion  \
# 0      image0000006.jpg   30  Woman            white   neutral
# 1      image0000060.jpg   34    Man            white   neutral
# 2      image0000061.jpg   44    Man            white     happy
# 3      image0000066.jpg   49    Man            white       sad
# 4      image0000106.jpg   30    Man            black     angry
# ...                 ...  ...    ...              ...       ...
# 14088  image0023909.jpg   16    Man            white   neutral
# 14089  image0023917.jpg   31  Woman            white   neutral
# 14090  image0023918.jpg   30  Woman            white  surprise
# 14091  image0023926.jpg   30    Man            black  surprise
# 14092  image0023930.jpg   31    Man  latino hispanic  surprise
#
#         Formatted_Image  Correct
# 0      image0000006.jpg    False
# 1      image0000060.jpg    False
# 2      image0000061.jpg    False
# 3      image0000066.jpg    False
# 4      image0000106.jpg    False
# ...                 ...      ...
# 14088  image0023909.jpg    False
# 14089  image0023917.jpg    False
# 14090  image0023918.jpg     True
# 14091  image0023926.jpg     True
# 14092  image0023930.jpg     True
#
# [14093 rows x 11 columns]

# %%
df_results.rename(columns={"Image": "pth"}, inplace=True)

# %%
df_affectnet_ground_th
# Out:
#        Unnamed: 0                        pth     label    relFCs  \
# 0               0     anger/image0000006.jpg  surprise  0.873142
# 1               1     anger/image0000060.jpg     anger  0.852311
# 2               2     anger/image0000061.jpg     anger  0.800957
# 3               3     anger/image0000066.jpg   disgust  0.843079
# 4               4     anger/image0000106.jpg     anger  0.849108
# ...           ...                        ...       ...       ...
# 28170       28170  surprise/image0034960.jpg  surprise  0.825263
# 28171       28171  surprise/image0034961.jpg  surprise  0.738646
# 28172       28172  surprise/image0034966.jpg  surprise  0.774524
# 28173       28173  surprise/image0034973.jpg   neutral  0.766952
# 28174       28174  surprise/image0042075.jpg   disgust  0.832160
#
#                   Image
# 0      image0000006.jpg
# 1      image0000060.jpg
# 2      image0000061.jpg
# 3      image0000066.jpg
# 4      image0000106.jpg
# ...                 ...
# 28170  image0034960.jpg
# 28171  image0034961.jpg
# 28172  image0034966.jpg
# 28173  image0034973.jpg
# 28174  image0042075.jpg
#
# [28175 rows x 5 columns]

# %% [markdown]
# ------------------

# %%
Test_data = pd.read_csv('face_analysis_results.csv')
Test_data

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

def display_images_with_labels(df, image_directory):
    # Number of images to display
    num_images = len(df)
    
    # Create a 3x2 grid
    fig, axes = plt.subplots(3, 2, figsize=(8, 8))
    
    # Flatten the axes array for easier indexing
    axes = axes.flatten()
    
    for i, (index, row) in enumerate(df.iterrows()):
        if i >= 6:  # Show only 6 images max (for the 3x2 grid)
            break
        
        image_path = os.path.join(image_directory, row['Image'])
        
        # Check if the image file exists
        if os.path.exists(image_path):
            img = Image.open(image_path)
            axes[i].imshow(img)
            axes[i].axis('off')
            
            # Add label for the image
            label = f"Age: {row['Age']}\nGender: {row['Gender']}\nRace: {row['Race']}"
            axes[i].set_title(label, fontsize=14)
        else:
            # If the image doesn't exist, show a placeholder
            axes[i].text(0.5, 0.5, 'Image not found', horizontalalignment='center', verticalalignment='center', fontsize=12)
            axes[i].axis('off')
    
    # Adjust layout to make space for titles
    plt.tight_layout()
    plt.show()


# Replace with your actual image directory
image_directory = 'data/archive/AffectNet/Train/_test'

# Display the images with labels
display_images_with_labels(Test_data, image_directory)

# %%
# Function to add an Age Group column
def add_age_group(df):
    # Define a function to assign age groups
    def get_age_group(age):
        lower_bound = (age // 10) * 10  # Get the lower bound of the age group
        upper_bound = lower_bound + 9  # The upper bound
        return f"{lower_bound}-{upper_bound}"

    # Apply the function to the Age column to create the Age Group column
    df['Age Group'] = df['Age'].apply(get_age_group)
    return df
df_with_age_group = add_age_group(Test_data)

df_with_age_group
